# %% [markdown]
# # <font color='red'> 실습 </font>

# %% [markdown]
# #  <font color='blue'>1. 다음을 실행하면 어떤 결과가 나올까요?  </font>

# %%
x = 10
x = 20
x =

# %% [markdown]
# #  <font color='blue'>2. 넓이와 둘레길이를 구하는 코드를 만드세요. a는 11, b는 7일때의 넓이와 둘레의 길이를 구하세요. </font>
# ![image.png](attachment:image.png)

# %%
a = 11
b = 7

# %%
area = a * b
perimeter = 2 * (a + b)

# %%
# Fix the TypeError by ensuring print is the built-in function
# Print the calculated area and perimeter
print("직사각형의 넓이:" , area)
print("직사각형의 둘레:" , perimeter)
# Out:
# 직사각형의 넓이: 77
# 직사각형의 둘레: 36

# %%
del print

# %% [markdown]
# # <font color='blue'> 4. 어떤 숫자 x가 주어졌을때, 그 숫자가 짝수인지 홀수인지 계산하는 코드를 작성하세요.  </font>
# - 3항 연산자 사용

# %%
x = 21
"짝수" if x % 2 == 0 else "홀수"
# Out:
# '홀수'

# %% [markdown]
# # <font color='blue'> 5. a의 길이가 20으로 주어졌을때, 표면적(area)와 부피(volume)을 구하세요. </font>
# ![image.png](data:image/png;base64,...)

# %%
a = 20

# %%
area = 6 * a**2
volume = a**3

# %%
print("표면적:", area)
print("부피:", volume)
# Out:
# 표면적: 2400
# 부피: 8000

# %% [markdown]
# #  <font color='blue'>6.     x 가 4, y 가 2일때 다음 식을 만족하는 z를 구하는 코드를 짜세요. </font>
# z = |x − y| *  (x + y)

# %%
x = 4
y = 2
a = abs(x - y)
b = (x + y)
z = abs(a) * b

# %%
print("z=",z)
# Out:
# z= 12

# %% [markdown]
# - 버그 안내고 문제를 잘 해결하는 인력인가 아닌가가 중요함.

# %% [markdown]
# # <font color='blue'> 7. 현재 속도가 90 KM/H 다. 이를 MP/H(Miles per hour) 로 계산하는 코드를 작성하세요.  </font>
# ![image.png](attachment:image.png)
# MPH = 0.6214 * KMH
