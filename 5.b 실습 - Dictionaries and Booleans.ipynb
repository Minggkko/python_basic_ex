# %% [markdown]
# # <font color='red'> *실습* </font>
# # <font color='red'> DICTIONARIES AND BOOLEANS </font>

# %% [markdown]
# # <font color='blue'> 1. 밸류들을 전부 곱한 값을 출력하는 코드를 만드세요. </font>

# %%
my_dict = {'data1':500,
           'data2':-10,
           'data3':300}

# %%
# 값만 추출
my_dict.values()
# Out:
# dict_values([500, -10, 300])

# %%
# list 형변환
val_list = list(my_dict.values())

# %%
# 전부 곱한 값을 출력
val_list[0]*val_list[1]*val_list[2]
# Out:
# -1500000

# %% [markdown]
# # <font color='blue'> 2. 각 학생별로, 중간과 기말의 평균점수를 구하세요.

# %%
student_details = [
  {'student_id' : 1, 'subject' : 'math', 'midterm' : 60, 'final' : 85},
  {'student_id' : 2, 'subject' : 'math', 'midterm' : 80, 'final' : 78},
  {'student_id' : 3, 'subject' : 'math', 'midterm' : 90, 'final' : 85}
]

# %%
# [] 대괄호 시작 대괄호로 끝나는 것을 리스트라고 함.
student_details[0]['midterm']
# {} 중괄호로 시작 중괄호로 끝나는 것을 딕셔너리라고 함.
# Out:
# 60

# %%
student_details[0]['midterm']+student_details[0]['final']/2
# Out:
# 102.5

# %%
student_details[1]['midterm']+student_details[1]['final']/2
# Out:
# 119.0

# %%
student_details[2]['midterm']+student_details[2]['final']/2
# Out:
# 132.5

# %%
student1 = (student_details[0]['midterm']+student_details[0]['final'])/2
student2 = (student_details[1]['midterm']+student_details[1]['final'])/2
student3 = (student_details[2]['midterm']+student_details[2]['final'])/2

# %%
print(student1)
print(student2)
print(student3)
# Out:
# 72.5
# 79.0
# 87.5

# %% [markdown]
# -선생님의 풀이-

# %%
# 한 학생의 중간성적 추출, 기말성적 추출
student_details[0]['midterm']
student_details[0]['final']
# Out:
# 85

# %%
# 첫 번째 학생 평균
st1_avg = (student_details[0]['midterm']+student_details[0]['final'])/2

# %%
# 두 번째 학생 평균
st2_avg = (student_details[1]['midterm']+student_details[1]['final'])/2

# %%
# 세 번째 학생 평균
st3_avg = (student_details[2]['midterm']+student_details[2]['final'])/2

# %%
st1_avg = (student_details[0]['midterm']+student_details[0]['final'])/2
st2_avg = (student_details[1]['midterm']+student_details[1]['final'])/2
st3_avg = (student_details[2]['midterm']+student_details[2]['final'])/2

# %%
print(st1_avg)
print(st2_avg)
print(st3_avg)
# Out:
# 72.5
# 79.0
# 87.5

# %% [markdown]
# # <font color='blue'> 3. 위에서 구한 평균점수를,"AVERAGE" 라는 키를 새로 만들어서, 각 학생의 딕셔너리에 추가하세요.

# %%
student_details[0]['AVERAGE'] = st1_avg
student_details
# Out:
# [{'student_id': 1,
#   'subject': 'math',
#   'midterm': 60,
#   'final': 85,
#   'average': 72.5,
#   'AVERAGE': 72.5},
#  {'student_id': 2,
#   'subject': 'math',
#   'midterm': 80,
#   'final': 78,
#   'average': 79.0,
#   'AVERAGE': 79.0},
#  {'student_id': 3,
#   'subject': 'math',
#   'midterm': 90,
#   'final': 85,
#   'average': 87.5,
#   'AVERAGE': 87.5}]

# %%
student_details[1]['AVERAGE'] = st2_avg
student_details
# Out:
# [{'student_id': 1,
#   'subject': 'math',
#   'midterm': 60,
#   'final': 85,
#   'average': 72.5,
#   'AVERAGE': 72.5},
#  {'student_id': 2,
#   'subject': 'math',
#   'midterm': 80,
#   'final': 78,
#   'average': 79.0,
#   'AVERAGE': 79.0},
#  {'student_id': 3,
#   'subject': 'math',
#   'midterm': 90,
#   'final': 85,
#   'average': 87.5,
#   'AVERAGE': 87.5}]

# %%
student_details[2]['AVERAGE'] = st3_avg
student_details
# Out:
# [{'student_id': 1,
#   'subject': 'math',
#   'midterm': 60,
#   'final': 85,
#   'average': 72.5,
#   'AVERAGE': 72.5},
#  {'student_id': 2,
#   'subject': 'math',
#   'midterm': 80,
#   'final': 78,
#   'average': 79.0,
#   'AVERAGE': 79.0},
#  {'student_id': 3,
#   'subject': 'math',
#   'midterm': 90,
#   'final': 85,
#   'average': 87.5,
#   'AVERAGE': 87.5}]

# %% [markdown]
# # <font color='blue'> 4. 각각의 숫자를,  제곱한 값으로 바꾸세요.
# dictionary = {'C1' : [10,20,30],
#               'C2' : [20,30,40]}

# %%
dictionary = {'C1' : [10,20,30], 'C2' : [20,30,40]}

# %%
# c1 : 첫번째 요소 제곱하기
dictionary['C1']= [dictionary['C1'][0]**2,dictionary['C1'][1]**2,dictionary['C1'][2]**2]
dictionary
# Out:
# {'C1': [10000, 160000, 810000], 'C2': [20, 30, 40]}

# %%
dictionary['C2']= [dictionary['C2'][0]**2,dictionary['C2'][1]**2,dictionary['C2'][2]**2]
dictionary
# Out:
# {'C1': [10000, 160000, 810000], 'C2': [160000, 810000, 2560000]}

# %% [markdown]
# # <font color='blue'>  5. (1)모든 키를 리스트로 출력하세요. (2) 모든 밸류를 리스트로 출력하세요. (3) 모든 밸류의 값을 다 더하세요.

# %%
my_salary = {"alex": 25, "sally": 28, "dina": 30}

# %%
my_salary.keys()
# Out:
# dict_keys(['alex', 'sally', 'dina'])

# %%
list(my_salary.keys())
# Out:
# ['alex', 'sally', 'dina']

# %%
list(my_salary.values())
# Out:
# [25, 28, 30]

# %%
val_list = list(my_salary.values())

# %%
list_val[0]+list_val[1]+list_val[2]
# Out:
# 83

# %%
sum(list_val)
# Out:
# 83

# %% [markdown]
# # <font color='blue'>  6. (a)딕셔너리의 길이를 구하세요.  (b) 나이에 대한 오름차순으로 정렬하세요.
# my_dict = {"sally": 23, "dina": 22, "holy": 50, "Joe": 10, "Peter": 44}

# %%
my_dict = {"sally": 23, "dina": 22, "holy": 50, "Joe": 10, "Peter": 44}

# %%
# (b) 나이에 대한 오름차순으로 정렬하세요.
sorted(my_dict.values())
# Out:
# [10, 22, 23, 44, 50]

# %%
len(my_dict)
# Out:
# 5
